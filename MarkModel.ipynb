# %%
# %matplotlib inline
import pandas
df = pandas.read_csv('Marks-Dataset.csv')

# %%
X = df[['Visits', 'Homework', 'Test']].values
Y = df['Exam'].values

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()
model.add(Dense(1, input_shape=(3,)))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 1)                 4
# ...
# Total params: 4
# Trainable params: 4
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(Adam(lr=0.8), 'mean_squared_error')

# %%
model.fit(X, Y, epochs=100)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 0s - loss: 1517.4528
# Epoch 2/100
# 32/32 [==============================] - 0s - loss: 1382.8988
# Epoch 3/100
# 32/32 [==============================] - 0s - loss: 1250.6185
# Epoch 4/100
# 32/32 [==============================] - 0s - loss: 109.4198
# Epoch 5/100
# 32/32 [==============================] - 0s - loss: 454.1240
# Epoch 6/100
# 32/32 [==============================] - 0s - loss: 924.7330
# Epoch 7/100
# 32/32 [==============================] - 0s - loss: 498.4442
# Epoch 8/100
# 32/32 [==============================] - 0s - loss: 52.1157
# Epoch 9/100
# 32/32 [==============================] - 0s - loss: 214.0926
# Epoch 10/100
# 32/32 [==============================] - 0s - loss: 521.6483
# Epoch 11/100
# 32/32 [==============================] - 0s - loss: 412.7915
# Epoch 12/100
# 32/32 [==============================] - 0s - loss: 100.6508
# Epoch 13/100
# ...

# %%
import coremltools
coreml_model = coremltools.converters.keras.convert(model, input_names='matrixVisitsHomeworkTest', output_names='examMark')
# Out:
# 0 : dense_1_input, <keras.engine.topology.InputLayer object at 0x118265b50>
# 1 : dense_1, <keras.layers.core.Dense object at 0x122a31c90>

# %%
coreml_model.author = 'Elena Yanovskaya'
coreml_model.short_description = 'Predicts the exam mark for neural networks.'

# %%
coreml_model.save('MarkModel.mlmodel')
